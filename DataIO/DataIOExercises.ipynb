# %% [markdown]
# # Data I/O Exercises

# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f', 'array', 'random']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
f = open('messy_data.dat', 'w')
import random
for i in range(100):
    for j in range(5):
        f.write(' ' * random.randint(0, 6))
        f.write('%0*.*g' % (random.randint(8, 12),
                            random.randint(5, 10),
                            100 * random.random()))
        if j != 4:
            f.write(',')
    f.write('\n')
f.close()

# %%
##Was forced to find this online as a substitute for "!head", as windows
##doesn't recognize any of Mac's functions you give us.

with open('messy_data.dat') as myfile:
    head=[myfile.next() for x in xrange(4)]
print head
# Out:
# ['    046.3069,000073.27322, 000049.73919,     94.1397326,      048.57734\n', '00035.13658,  3.6159957,    039.6867,  000069.71914,   50.855548\n', '029.6328558,     0000080.3218, 18.27158,      000097.908, 22.46163\n', '    012.5556707,   0078.1201,    81.9260847,  39.6522801,  10.20704818\n']

# %% [markdown]
# (a) Write a program that reads in the contents of "messy_data.dat" and extracts the numbers from each line, using the string manipulations we used in section 1 (remember that float() will convert a suitable string to a floating-point number).

# %%
##This program puts all of the numbers in an array.

contents = open('messy_data.dat').read()
out = open('messy_data.dat','w')
out.write(contents.replace(',',' '))
out.close

m_arr=[]
for line in open('messy_data.dat'):
    arr=[]
    sep = line.split()
    for item in sep:
        item = float(item)
        arr.append(item)
    m_arr.append(arr)
print m_arr
# Out:
# [[46.3069, 73.27322, 49.73919, 94.1397326, 48.57734], [35.13658, 3.6159957, 39.6867, 69.71914, 50.855548], [29.6328558, 80.3218, 18.27158, 97.908, 22.46163], [12.5556707, 78.1201, 81.9260847, 39.6522801, 10.20704818], [7.538382, 69.097753, 78.78245998, 38.73214784, 20.97527878], [12.430511, 46.5527, 50.0766202, 38.297, 1.213631], [44.591, 58.327205, 6.523118, 66.48268456, 54.88644194], [31.8539809, 7.858541, 66.118122, 24.081, 33.7093995], [13.3897, 3.51788, 1.308368, 61.761, 43.404924], [52.462, 82.34602532, 86.10152, 24.0198, 80.4518], [16.55229, 81.70385, 94.5082509, 38.88308, 25.662776], [22.77889842, 26.4477, 62.26616038, 31.33754401, 7.9568], [64.84809, 91.5582, 51.465229, 11.3917, 3.072849], [65.971, 50.9719, 93.326, 33.413291, 45.716125], [12.6222, 22.7824, 32.7033, 1.5920503, 43.70213], [66.4757939, 57.5478, 40.7622, 61.301, 12.8296], [4.09158251, 98.87687086, 29.939, 46.95133, 16.784], [72.15296, 96.26, 16.910833, 57.6178599, 99.81796017], [5.670308, 0.22017476, 94.5952239, 88.2013033, 50.692943], [70.86233, 12.7722, 0.4248184974, 21.687, 45.313855], [93.57497885, 93.35035312, 20.0142917, 57.63980495, 88.314], [77.13140576, 49.326, 26.384, 46.13203828, 42.716705], [81.50993971, 81.3541, 11.314132, 49.837, 55.89796121], [18.81651922, 37.032, 83.067, 39.40056, 33.9265], [31.5516378, 96.506033, 84.23623361, 30.4022058, 35.7431962], [97.25, 35.635188, 76.103, 2.005475, 62.674], [52.041, 86.2635, 26.491296, 67.4189, 61.63416306], [14.62569, 50.1253, 74.3434144, 34.95454892, 3.1336735], [96.815, 33.0020409, 81.5988, 5.6924, 71.233], [13.4071388, 64.6300566, 16.45284, 39.353533, 81.7785028], [4.8148523, 40.2993108, 9.1162969, 17.5302, 52.048049], [38.801061, 74.3596, 48.5698, 37.5856116, 94.95796], [41.346, 31.93371, 7.4612529, 81.7253034, 11.56979], [98.91196, 71.51111, 24.088288, 30.7635981, 30.170566], [62.63920298, 99.338269, 23.2649058, 46.30373833, 6.02275455], [90.641771, 74.84341665, 70.611156, 34.6193, 38.508], [35.997, 16.749, 62.6866, 27.32734, 69.00872974], [2.373, 62.06, 50.684055, 84.5112, 22.766], [13.9178, 15.9416, 31.52984196, 50.838, 41.92387], [68.0202328, 12.05575, 80.15566746, 3.31772, 76.846466], [92.62487684, 42.823, 92.5318434, 1.899058, 8.0275736], [44.5117, 84.7239438, 20.7325, 38.58652849, 85.93471], [23.75281, 99.2827, 77.1857651, 40.86467, 5.241419], [63.10479521, 15.2625, 59.48930277, 9.24785, 60.5708127], [4.8075717, 73.39662872, 26.998875, 40.022623, 50.1440385], [49.8819, 47.9632949, 81.8105, 2.744032049, 72.915], [51.1978, 6.2805, 84.38290623, 97.5840724, 39.633], [79.863412, 65.74831, 79.15195, 23.127, 12.16693556], [76.715, 95.83141, 87.87619, 39.9561003, 25.6395], [33.0613, 37.5308102, 26.299405, 48.91217, 37.3351], [5.323744, 10.368734, 85.44673, 21.02621, 39.2231256], [94.654, 37.136, 14.2748, 95.574349, 82.299], [7.25117371, 94.638, 98.666528, 28.637505, 19.6378796], [64.1855306, 88.2001, 85.779, 74.34784, 20.4619], [21.84967, 36.3626, 29.4290804, 65.943, 82.376372], [30.878, 14.156, 45.291, 49.342, 76.137428], [46.782733, 99.04195155, 14.50774, 74.43324968, 27.8876142], [15.93529, 19.325, 78.562, 60.0061, 36.9701446], [52.8, 51.269, 99.800202, 90.8034], [33.998585, 5.729548306, 5.934416, 53.907, 83.70703104], [94.1410048, 25.012, 43.88566703, 57.97426015, 23.7486851], [2.939, 76.56560912, 85.311586, 19.152, 94.3356859], [92.08106835, 78.22038, 10.98869, 62.407, 38.85155], [43.96355978, 40.902, 8.7225, 55.02206, 73.49763], [97.824, 20.32601645, 30.4336, 55.707, 45.47459081], [63.5219759, 94.314186, 72.319, 96.18982194, 89.218], [62.561948, 5.70963, 69.796, 95.042834, 92.769], [23.416, 61.5961419, 49.05963, 61.6604663, 95.36011464], [40.03196608, 1.25769931, 39.1850488, 73.93606, 49.3761], [8.4492, 92.2947624, 54.9011739, 59.50751, 62.9518], [44.42575674, 19.884, 70.82917798, 53.984022, 72.22281], [10.5142931, 13.83, 86.3678745, 60.132334, 43.0544], [78.101, 68.90540699, 78.253376, 74.2909, 84.92], [29.48856993, 4.79439014, 86.645244, 16.13316, 97.714007], [31.887615, 22.891, 0.17508,  ...

# %% [markdown]
# (b) Next write out a new file named "clean_data.dat". The new file should contain the same data as the old file, but with uniform formatting and aligned columns.

# %%
#I decided to make a series of arrays that were taken from my array in the 
#last part and put them into separate arrays based on their columns then I 
#will column_stack them and save them as the new file.

v=[]
w=[]
x=[]
y=[]
z=[]
for array in m_arr:
    v1 = array[0]
    w1 = array[1]
    x1 = array[2]
    y1 = array[3]
    z1 = array[3]
    v.append(v1)
    w.append(w1)
    x.append(x1)
    y.append(y1)
    z.append(z1)

myheader = "Clean Data Output\n  v         w         x         y         z     "
DataOut = column_stack((v,w,x,y,z))
savetxt('clean_data.dat', DataOut, fmt=('%5.3e','%5.3e','%5.3e','%5.3e','%5.3e'),header=myheader)

# !more clean_data.dat
# Out:
# # Clean Data Output
# #   v         w         x         y         z
# 4.631e+01 7.327e+01 4.974e+01 9.414e+01 9.414e+01
# 5.754e+01 1.223e+01 5.103e+01 5.712e+01 5.712e+01
# 6.106e-01 7.776e+01 8.428e+01 3.332e+01 3.332e+01
# 8.161e+00 8.143e+01 5.885e+01 8.141e+01 8.141e+01
# 9.205e+00 3.367e+01 7.099e+00 5.155e+01 5.155e+01
# 7.885e+01 8.715e+01 1.956e+01 2.631e+01 2.631e+01
# 3.656e+01 3.077e+01 7.577e+01 4.600e+01 4.600e+01
# 6.766e+01 7.920e+00 8.975e+01 7.635e+01 7.635e+01
# 6.129e+01 9.166e+00 7.441e+01 3.927e+01 3.927e+01
# 4.116e+01 3.733e+01 4.157e+01 4.617e+01 4.617e+01
# 5.298e+01 9.205e+01 3.063e+01 9.326e+01 9.326e+01
# 3.457e+01 6.038e+01 9.658e+01 3.258e-01 3.258e-01
# 4.956e+01 5.212e+00 6.332e-01 5.587e+00 5.587e+00
# 8.233e+00 9.408e+01 6.831e+00 8.767e+01 8.767e+01
# 1.274e+00 2.077e+01 4.543e+01 6.369e+01 6.369e+01
# 3.231e+01 3.368e+01 3.040e+01 2.899e+00 2.899e+00

# %% [markdown]
# #### Here is the loadtxt and savetxt function part

# %%
data = np.loadtxt("messy_data.dat", delimiter=',')
np.savetxt("clean_data.dat",data,delimiter='\t',fmt="%8.5f")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-270e0307748f> in <module>()
# ----> 1 data = np.loadtxt("messy_data.dat", delimiter=',')
#       2 np.savetxt("clean_data.dat",data,delimiter='\t',fmt="%8.5f")
#
# C:\Users\Bryce\Anaconda\lib\site-packages\numpy\lib\npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     841                 vals = [vals[i] for i in usecols]
#     842             # Convert each value according to its column and store
# --> 843             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     844             # Then pack it according to the dtype's nesting
#     845             items = pack_items(items, packing)
#
# ValueError: invalid literal for float(): 046.3069 000073.27322  000049.73919      94.1397326       048.57734

# %% [markdown]
# ## Solution Code

# %%
# Don't modify this: it simply writes the example file
f = open('messy_data2.dat', 'w')
import random
for i in range(100):
    for j in range(5):
        f.write(' ' * random.randint(0, 6))
        f.write('%0*.*g' % (random.randint(8, 12),
                            random.randint(5, 10),
                            100 * random.random()))
        if j != 4:
            f.write(',')
    f.write('\n')
f.close()

# %%
# Look at the first four lines of the file:
# !head -4 messy_data2.dat

# %% [markdown]
# (a) Write a program that reads in the contents of "messy_data.dat" and extracts the numbers from each line, using the string manipulations we used in section 1 (remember that float() will convert a suitable string to a floating-point number).

# %%
for line in open('messy_data2.dat'):
    for item in line.split(','):
        print float(item),
        print '   ',
    print ' '

# %% [markdown]
# (b) Next write out a new file named "clean_data.dat". The new file should contain the same data as the old file, but with uniform formatting and aligned columns.

# %%
fout = open('clean_data2.dat', 'w')
for line in open('messy_data2.dat'):
    for item in line.split(','):
        fout.write('%8.5f'%float(item))
        fout.write('\t')
    fout.write('\n')
fout.close()

# %%
# !head -5 clean_data2.dat

# %% [markdown]
# (c) Now re-do the same task using NumPy's loadtxt and savetxt functions.

# %%
data = np.loadtxt("messy_data2.dat", delimiter=',')
np.savetxt("clean_data2.dat", data, delimiter='\t', fmt="%8.5f")

# %%
# !head -5 clean_data2.dat
