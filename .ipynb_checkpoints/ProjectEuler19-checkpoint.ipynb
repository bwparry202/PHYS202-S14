# %% [markdown]
# # Project Euler Problem 19

# %% [markdown]
# You are given the following information, but you may prefer to do some research for yourself.
#
# 1 Jan 1900 was a Monday.
#
# Thirty days has September,
#
# April, June and November.
#
# All the rest have thirty-one,
#
# Saving February alone,
#
# Which has twenty-eight, rain or shine.
#
# And on leap years, twenty-nine.
#
# A leap year occurs on any year evenly divisible by 4, but not on a century unless it is divisible by 400.
#
# How many Sundays fell on the first of the month during the twentieth century (1 Jan 1901 to 31 Dec 2000)?

# %%
import numpy as np

def sundays_in_year(year,startday):
    if year % 4 == 0 and year % 100 != 0:
        day1 = startday
        num_sunday = 0
        #January
        Jan = np.zeros(31, dtype = bool)
        Jan[0] = True
        for day in range(len(Jan)):
            if Jan[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #February
        Feb = np.zeros(29, dtype = bool)
        Feb[0] = True
        for day in range(len(Feb)):
            if Feb[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #March
        Mar = np.zeros(31, dtype = bool)
        Mar[0] = True
        for day in range(len(Mar)):
            if Mar[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #April
        April = np.zeros(30, dtype = bool)
        April[0] = True
        for day in range(len(April)):
            if April[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #May
        May = np.zeros(31, dtype = bool)
        May[0] = True
        for day in range(len(May)):
            if May[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #June
        Jun = np.zeros(30, dtype = bool)
        Jun[0] = True
        for day in range(len(Jun)):
            if Jun[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #July
        Jul = np.zeros(31, dtype = bool)
        Jul[0] = True
        for day in range(len(Jul)):
            if Jul[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #August
        Aug = np.zeros(31, dtype = bool)
        Aug[0] = True
        for day in range(len(Aug)):
            if Aug[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #September
        Sep = np.zeros(30, dtype = bool)
        Sep[0] = True
        for day in range(len(Sep)):
            if Sep[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #October
        Oct = np.zeros(31, dtype = bool)
        Oct[0] = True
        for day in range(len(Oct)):
            if Oct[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #November
        Nov = np.zeros(30, dtype = bool)
        Nov[0] = True
        for day in range(len(Nov)):
            if Nov[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #December
        Dec = np.zeros(31, dtype = bool)
        Dec[0] = True
        for day in range(len(Dec)):
            if Dec[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        return num_sunday
    else:
        day1 = startday
        num_sunday = 0
        #January
        Jan = np.zeros(31, dtype = bool)
        Jan[0] = True
        for day in range(len(Jan)):
            if Jan[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #February
        Feb = np.zeros(28, dtype = bool)
        Feb[0] = True
        for day in range(len(Feb)):
            if Feb[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #March
        Mar = np.zeros(31, dtype = bool)
        Mar[0] = True
        for day in range(len(Mar)):
            if Mar[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #April
        April = np.zeros(30, dtype = bool)
        April[0] = True
        for day in range(len(April)):
            if April[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #May
        May = np.zeros(31, dtype = bool)
        May[0] = True
        for day in range(len(May)):
            if May[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #June
        Jun = np.zeros(30, dtype = bool)
        Jun[0] = True
        for day in range(len(Jun)):
            if Jun[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #July
        Jul = np.zeros(31, dtype = bool)
        Jul[0] = True
        for day in range(len(Jul)):
            if Jul[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #August
        Aug = np.zeros(31, dtype = bool)
        Aug[0] = True
        for day in range(len(Aug)):
            if Aug[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #September
        Sep = np.zeros(30, dtype = bool)
        Sep[0] = True
        for day in range(len(Sep)):
            if Sep[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #October
        Oct = np.zeros(31, dtype = bool)
        Oct[0] = True
        for day in range(len(Oct)):
            if Oct[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #November
        Nov = np.zeros(30, dtype = bool)
        Nov[0] = True
        for day in range(len(Nov)):
            if Nov[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        #December
        Dec = np.zeros(31, dtype = bool)
        Dec[0] = True
        for day in range(len(Dec)):
            if Dec[day] == True and (((day1 + 2) % 7) == 0):
                num_sunday += 1
                day1 += 1
            else:
                day1 += 1
        return num_sunday

sundays=0
day = 0
for year in range(1901,2001):
    if year % 4 == 0 and year % 100 != 0:
        sundays += sundays_in_year(year,day)
        day += 366
    else:
        sundays += sundays_in_year(year,day)
        day += 365
print "Number of sundays occuring on the first day of the month \nfrom the beginning of 1901 to the end of 2000:",sundays
# Out:
# Number of sundays occuring on the first day of the month
# from the beginning of 1901 to the end of 2000: 171

# %% [markdown]
# What my code does is look at every year and keep a count of every day as it goes along, checking to see that if at the beginning of the month if the date+2 is evenly divisible by 7, I figured this by using the fact that the first day in 1901 is a Tuesday and figuring out what number's Sunday landed on, it turns out that it is on 5,12,19, etc. Using this I developed my code around that.
#
# I know it is quite lengthy but it does output the correct value of 171.
