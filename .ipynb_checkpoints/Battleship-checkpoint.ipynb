# %% [markdown]
# # Battleship

# %%
from ipythonblocks import BlockGrid
from random import randint

print "Let's play Battleship!!"

#Creating the grid
grid_size = int(raw_input("How large of a grid do you want to play on? (Inputting 8 will return an 8x8 grid)(Input values range from 8 to 14): "))    

#This function checks to see if the grid size is acceptable.

def grid_checker(grid_size):
    if grid_size <= 7:
        print "Ooops, that's too small, needs to be at least 8"
        grid_size_repeat = int(raw_input("How large of a grid: "))
        grid_checker(grid_size_repeat)
    elif grid_size >= 15:
        print "Ooops, that's too big, needs to be 14 or less"
        grid_size_repeat = int(raw_input("How large of a grid: "))
        grid_checker(grid_size_repeat)
    else:
        return grid_size
                
p = grid_checker(grid_size)
grid = BlockGrid(p,p, fill=(123,195,220))
        
#Defining how many turns you want
turns = int(raw_input("Enter the number of turns you want(10+ is reccomended): "))

print "Awesome! Let's play Battleship!"
grid.show()

#Now we will define where our ship is
#Generally, my function will pick whether the ship will be oriented by
#the column or the row, then it will place the battleship

#This is just a few random generator functions that I will use later.

def rand_column(grid_size):
    return randint(0,grid_size)

def rand_row(grid_size):
    return randint(0,grid_size)

def rand_direction_up_down():
    d = randint(1,2)
    if d == 1:
        return "down"
    elif d == 2:
        return "up"
    
def rand_direction_right_left():    
    r = randint(1,2)
    if r == 1:
        return "right"
    elif r == 2:
        return "left"

#This is the column/row orientation, if z = 0 the ship will be oriented vertically, 
#if z = 1 the ship will be oriented horizontally. The ship will be anywhere 
#from 4 to 6 blocks long, depending on how big the board is. 4 ships long
#It tests to see how far away it is from the wall and then adds the other blocks
#either up down right or left of the inital random position.

def ship_placer():
    z = randint(0,1)       
    x1 = rand_column(p)
    y1 = rand_row(p)
    if z == 0:                         
        updown = rand_direction_up_down()
        x2 = x1
        x3 = x1
        if updown == "up":
            if y1 >= 2:
                y2 = y1 - 1
                y3 = y1 - 2
            elif y1 >= 1:
                y2 = y1 + 1
                y3 = y1 - 1
            else:
                y2 = y1 + 1
                y3 = y1 + 2
        if updown == "down":
            if y1 <= p-2:
                y2 = y1 + 1
                y3 = y1 + 2
            elif y1 <= p-1:
                y2 = y1 - 1
                y3 = y1 + 1
            else:
                y2 = y1 - 1
                y3 = y1 - 2               
        
    if z == 1:
        rightleft = rand_direction_right_left()
        y2 = y1
        y3 = y1
        if rightleft == "right":
            if x1 >= 2:
                x2 = x1 - 1
                x3 = x1 - 2
            elif x1 >= 1:
                x2 = x1 + 1
                x3 = x1 - 1
            else:
                x2 = x1 + 1
                x3 = x1 + 2
        if rightleft == "left":
            if x1 <= p-2:
                x2 = x1 + 1
                x3 = x1 + 2
            elif x1 <= p-1:
                x2 = x1 - 1
                x3 = x1 + 1
            else:
                x2 = x1 - 1
                x3 = x1 - 2
    ship = [x1,y1,x2,y2,x3,y3]
    return ship

#The following just extracts the data from the random ship placer, and puts it into variables we can work
#with for the guesser section of the code.

ship = ship_placer()
y1 = ship[0]
x1 = ship[1]
y2 = ship[2]
x2 = ship[3]
y3 = ship[4]
x3 = ship[5]
    

#Here is the code for the steps and when the player guesses where the ship is.
#It works by testing if you have won first, then it tests if your guess is one of the
#places where the ship is. It also includes the cases from the previous battleship code,
#where it tests if you have gone off of the board.

turn = 1
while turn <= turns:
    print "Turn: "+str(turn)
    guess_y = int(raw_input("Guess Row: "))    
    guess_x = int(raw_input("Guess Column: "))
    if grid[x1,y1] == (255,0,0) and grid[x2,y2] == (255,0,0) and grid[x3,y3] == (255,0,0):
        print "Congratulations! You sunk my battleship!"
        grid.show()
        break
    elif [guess_x,guess_y] == [x1,y1] or [guess_x,guess_y] == [x2,y2] or [guess_x,guess_y] == [x3,y3]:
        grid[guess_x,guess_y] = (255,0,0)
        grid.show()
        turn += 1
        if turn >= turns+1:
            print "Game Over, here's where the battleship was"
            if grid[x1,y1] == (123,195,220):
                grid[x1,y1] = (128,128,128)
            else:
                grid[x1,y1] = (255,0,0)
                
            if grid[x2,y2] == (123,195,220):
                grid[x2,y2] = (128,128,128)
            else:
                grid[x2,y2] = (255,0,0)
        
            if grid[x3,y3] == (123,195,220):
                grid[x3,y3] = (128,128,128)
            else:
                grid[x3,y3] = (255,0,0)
            grid.show()
        
    else:
        if (guess_y < 0 or guess_y > grid_size) or (guess_x < 0 or guess_x > grid_size):
            print "Oops, that's not even in the ocean."
        elif grid[guess_x,guess_y] == (0,0,139):
            print "You guessed that one already."
        else:
            print "You missed my battleship!"
            grid[guess_x,guess_y] = (0,0,139)
            grid.show()
            turn += 1
            if turn >= turns+1:
                print "Game Over, here's where the battleship was"
                if grid[x1,y1] == (123,195,220):
                    grid[x1,y1] = (128,128,128)
                else:
                    grid[x1,y1] = (255,0,0)
                
                if grid[x2,y2] == (123,195,220):
                    grid[x2,y2] = (128,128,128)
                else:
                    grid[x2,y2] = (255,0,0)
        
                if grid[x3,y3] == (123,195,220):
                    grid[x3,y3] = (128,128,128)
                else:
                    grid[x3,y3] = (255,0,0)
                grid.show()
# Out:
# Let's play Battleship!!
# How large of a grid do you want to play on? (Inputting 8 will return an 8x8 grid)(Input values range from 8 to 14): 10
# Enter the number of turns you want(10+ is reccomended): 10
# Awesome! Let's play Battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks6a6830f2-9b89-4ece-9e7e-3451bf17b36a td {border: 1px solid white;}</style><table id="blocks6a6830f2-9b89-4ece-9e7e-3451bf17b36a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 8]&#10;Color: (123, 195, 220)" style="wi ...
# Turn: 1
# Guess Row: 4
# Guess Column: 2
# You missed my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksa6c80191-b381-4970-a86d-f6a4805b8750 td {border: 1px solid white;}</style><table id="blocksa6c80191-b381-4970-a86d-f6a4805b8750" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 4]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [2, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 8]&#10;Color: (123, 195, 220)" style="width: 20p ...
# Turn: 2
# Guess Row: 7
# Guess Column: 5
# You missed my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks69cba978-124a-475b-9062-88ab8c01c6eb td {border: 1px solid white;}</style><table id="blocks69cba978-124a-475b-9062-88ab8c01c6eb" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 4]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [2, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 8]&#10;Color: (123, 195, 220)" style="width: 20p ...
# Turn: 3
# Guess Row: 1
# Guess Column: 4
# You missed my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blockse7c663eb-f5f7-4da5-ae0f-188b4122504f td {border: 1px solid white;}</style><table id="blockse7c663eb-f5f7-4da5-ae0f-188b4122504f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 4]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [2, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 8]&#10;Color: (123, 195, 220)" style="width: 20p ...
# Turn: 4
# Guess Row: 6
# Guess Column: 3
# You missed my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksc6870854-f0ce-4b82-ae67-a7ae0e3fcad2 td {border: 1px solid white;}</style><table id="blocksc6870854-f0ce-4b82-ae67-a7ae0e3fcad2" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 4]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [2, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 8]&#10;Color: (123, 195, 220)" style="width: 20p ...
# Turn: 5
# Guess Row: 8
# Guess Column: 1
# You missed my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks78d401a1-8465-44ed-8816-0aca23f5b318 td {border: 1px solid white;}</style><table id="blocks78d401a1-8465-44ed-8816-0aca23f5b318" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [1, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 4]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [2, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 8]&#10;Color: (123, 195, 220)" style="width: 20px; heigh ...
# Turn: 6
# Guess Row: 9
# Guess Column: 9
# You missed my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksf9dc0767-7bec-49be-b02f-08173fa7a9a9 td {border: 1px solid white;}</style><table id="blocksf9dc0767-7bec-49be-b02f-08173fa7a9a9" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [1, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 4]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [2, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 8]&#10;Color: (123, 195, 220)" style="width: 20px; heigh ...
# Turn: 7
# Guess Row: 5
# Guess Column: 3
# You missed my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksfe53c946-878b-4bef-8183-b4e63a6433e7 td {border: 1px solid white;}</style><table id="blocksfe53c946-878b-4bef-8183-b4e63a6433e7" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [1, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 4]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [2, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 8]&#10;Color: (123, 195, 220)" style="width: 20px; heigh ...
# Turn: 8
# Guess Row: 8
# Guess Column: 8
# You missed my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks5eed2df0-f4ec-4199-a705-0fcaf3a8608f td {border: 1px solid white;}</style><table id="blocks5eed2df0-f4ec-4199-a705-0fcaf3a8608f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [1, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 4]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [2, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 8]&#10;Color: (123, 195, 220)" style="width: 20px; heigh ...
# Turn: 9
# Guess Row: 9
# Guess Column: 3
# You missed my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks90c0ecab-f518-4de6-a8aa-01de7109e082 td {border: 1px solid white;}</style><table id="blocks90c0ecab-f518-4de6-a8aa-01de7109e082" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [1, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 4]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [2, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 8]&#10;Color: (123, 195, 220)" style="width: 20px; heigh ...
# Turn: 10
# Guess Row: 1
# Guess Column: 1
# You missed my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksaa271edf-56da-4032-ad68-6e963366ebc7 td {border: 1px solid white;}</style><table id="blocksaa271edf-56da-4032-ad68-6e963366ebc7" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [1, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [1, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 4]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [2, 5]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px; ...
# Game Over, here's where the battleship was
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks4287e398-c7ec-47f8-a4c6-21c7df55effd td {border: 1px solid white;}</style><table id="blocks4287e398-c7ec-47f8-a4c6-21c7df55effd" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 5]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [0, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 1]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [1, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 4]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 5]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [1, 9]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 1]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 2]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 3]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 4]&#10;Color: (0, 0, 139)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 139);"></td><td title="Index: [2, 5]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [2, 6]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 7]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(123, 195, 220);"></td><td title="Index: [2, 8]&#10;Color: (123, 195, 220)" style="width: 20px; height: 20px;background-color: rgb(12 ...
